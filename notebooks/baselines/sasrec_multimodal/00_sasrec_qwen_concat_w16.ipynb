# %% [markdown]
# # SASRec Multimodal

# %%
from pathlib import Path
import json
import pandas as pd

ROOT = Path.cwd().resolve()
while not (ROOT / "scripts").exists() and ROOT.parent != ROOT:
    ROOT = ROOT.parent

RUN_NAME = "sasrec_qwen_concat_w16"
OUTPUT_DIR = ROOT / "reports/sasrec_multimodal" / RUN_NAME
OUTPUT_DIR

# %%
# !python "{ROOT / 'scripts/experiments/sasrec_multimodal_train.py'}" --epochs 30 --patience 4 --batch-size 2048 --eval-batch-size 1024 --max-reserved-gb 14 --output-dir "{OUTPUT_DIR}"

# %%
summary = json.loads((OUTPUT_DIR / "summary.json").read_text(encoding="utf-8"))
summary

# %%
history = pd.read_csv(OUTPUT_DIR / "history_val.csv")
history[["epoch", "train_loss", "recall@1", "recall@5", "recall@10", "ndcg@10", "mrr@10", "coverage@10"]]
